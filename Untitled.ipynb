# %%
import pandas as pd
pd.options.display.max_columns=None
pd.options.display.max_rows=None

# %%
data=pd.read_csv('EDWF workers data.Final.csv')

# %%
data.T[:10]
# Out:
#                                                                    0  \
# Erode District Women's Federation  Spinning/Garments/ Dyeing labours
# Unnamed: 1                                                       NaN
# Unnamed: 2                                                       NaN
# Unnamed: 3                                                       NaN
# Unnamed: 4                                                       NaN
# Unnamed: 5                                                       NaN
# Unnamed: 6                                                       NaN
# Unnamed: 7                                                       NaN
# Unnamed: 8                                                       NaN
# Unnamed: 9                                                       NaN
#
#                                                  1  \
# Erode District Women's Federation    Village Name:
# Unnamed: 1                                     NaN
# ...
